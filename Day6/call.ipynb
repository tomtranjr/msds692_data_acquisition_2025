# %%
import requests

# %%
response = requests.get(
    "http://127.0.0.1:8000/retrieve_and_store",
    {"url": "https://data.sfgov.org/resource/wg3w-h783"},
)
response.text
# Out:
# '{"detail":"Could not call https://data.sfgov.org/resource/wg3w-h783\\n                                     Error Message: 400: Was able to call https://data.sfgov.org/resource/wg3w-h783,                                    but may not have permission to store in GCS.                                    Error Message: [Errno 2] No such file or directory: \'/Users/tomtranjr/.ssh/wide-pulsar-469815-n5-116277ab1c75.json\'"}'
