# %%
import requests

# %% [markdown]
# GET Request

# %%
url = 'https://www.usfca.edu/arts-sciences/programs/graduate/data-science'
headers = ''
r = requests.get(url, headers=headers) # r is a resopnse
print(r.headers)
print(r.content)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '240748', 'Cache-Control': 'max-age=21600, public', 'Content-Language': 'en', 'Content-Type': 'text/html; charset=UTF-8', 'Etag': 'W/"1756182134"', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Last-Modified': 'Tue, 26 Aug 2025 04:22:14 GMT', 'Server': 'nginx', 'Strict-Transport-Security': 'max-age=300', 'X-Content-Type-Options': 'nosniff', 'X-Drupal-Cache': 'HIT', 'X-Drupal-Dynamic-Cache': 'MISS', 'X-Frame-Options': 'ALLOW-FROM https://usfca.instructure.com', 'X-Generator': 'Drupal 9 (https://www.drupal.org)', 'X-Pantheon-Styx-Hostname': 'styx-fe2-a-c4dc75986-7qdb4', 'X-Styx-Req-Id': 'cefdf3ab-8240-11f0-98ea-56ebceeeb27c', 'X-Ua-Compatible': 'IE=edge', 'Age': '0', 'Accept-Ranges': 'bytes', 'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish, 1.1 varnish', 'Date': 'Tue, 26 Aug 2025 05:52:11 GMT', 'X-Served-By': 'cache-chi-kigq8000179-CHI, cache-pao-kpao1770060-PAO, cache-pao-kpao1770083-PAO, cache-pao-kpao1770083-PAO', 'X-Cache': 'MISS, MISS, M
# ...

# %%
url = "https://www.google.com/search"
payload = {"q":"USF Data Science"}
headers = ''

r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.content)
# Out:
# https://www.google.com/search?q=USF+Data+Science
# ...

# %% [markdown]
# POST Request

# %%
url = 'https://www.w3schools.com/action_page.php'
data = {'key': 'value'}
header = ''

r = requests.post(url, data=data, headers=header)
print(r.headers)
print(r.content)
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '672', 'Content-Security-Policy': "frame-ancestors 'self' https://mycourses.w3schools.com https://pathfinder.w3schools.com;", 'X-Content-Security-Policy': "frame-ancestors 'self' https://mycourses.w3schools.com https://pathfinder.w3schools.com;", 'Cache-Control': 'public, max-age=3600', 'Expires': 'Tue, 26 Aug 2025 06:52:12 GMT', 'Date': 'Tue, 26 Aug 2025 05:52:12 GMT', 'Connection': 'keep-alive', 'X-loc': 'true'}
# ...
